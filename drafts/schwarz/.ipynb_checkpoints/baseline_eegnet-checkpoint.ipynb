# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import matplotlib as mpl
import mne
import pathlib
import pytorch_lightning as pl
import torch
import torcheeg
import xgboost
import wandb

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../code')
# from preprocessing import preprocess_data
from transforms import _compose, _randomcrop, totensor, \
channelwide_norm, channelwise_norm, _clamp, toimshape, \
_labelcenter, _labelnorm, _labelbin
from functools import partial
from data import BrainAgeDataset

# %%
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.tuner import Tuner

# %% [markdown]
# ### Interface with data

# %%
data_dir = pathlib.Path("/data0/practical-sose23/brain-age/data/bap/")
assert data_dir.is_dir()

data_dir_healthy = data_dir / "healthy_controls/preprocessed"
assert data_dir_healthy.is_dir()

data_dir_chronic_pain = data_dir / "chronic_pain_patients"
assert data_dir_chronic_pain.is_dir()

# %%
eeg_files_all = list(data_dir.rglob("*.vhdr"))

eeg_files_raw = [f for f in eeg_files_all if not "preprocessed" in str(f)]
eeg_files_preprocessed = [f for f in eeg_files_all if "preprocessed" in str(f)]

eeg_files_healthy = list(data_dir_healthy.rglob("*.vhdr"))
eeg_files_chronic_pain = [f for f in eeg_files_preprocessed if "chronic_pain_patients" in str(f)]

# %% [markdown]
# ### Analyze the subject data

# %%
def get_subj_id(eeg_file: pathlib.Path):
    return eeg_file.stem.split("_")[-3]

def get_age(df_subj, eeg_file: pathlib.Path):
    subj_id = get_subj_id(eeg_file)
    return df_subj[df_subj["Subject ID"] == subj_id]["Age(years)"].values[0]

# %% [markdown]
# #### Load clinical data

# %%
f_subj = data_dir / "clinical_data_updated_2020-08-04.ods"
assert f_subj.is_file()

# %%
df_subj_chronic_pain = pd.read_excel(f_subj, sheet_name=0, engine="odf", skiprows=1)
df_subj_healthy = pd.read_excel(f_subj, sheet_name=1, engine="odf", skiprows=0)

df_subj = pd.concat([df_subj_chronic_pain, df_subj_healthy])
df_subj["Age(years)"] = df_subj["Age(years)"].fillna(df_subj["Age (years)"])

print(f"# recorded subjects:      {len(df_subj)}")
print(f"# raw eeg files:          {len(eeg_files_raw)}")
print(f"# preprocessed eeg files: {len(eeg_files_preprocessed)}")

zfill_ints = lambda x:str(x).zfill(3) if type(x) else x
df_subj_chronic_pain["Subject ID"] = df_subj_chronic_pain["Subject ID"].astype(str).map(zfill_ints)
df_subj_healthy["Subject ID"] = df_subj_healthy["Subject ID"].astype(str).map(zfill_ints)
df_subj["Subject ID"] = df_subj["Subject ID"].astype(str).map(zfill_ints)

df_subj
# Out:
# # recorded subjects:      189
# # raw eeg files:          190
# # preprocessed eeg files: 189
#    Subject ID     Project prefix  Age(years) Sex (m/f)  Pain duration(months)  \
# 0        VP02  chronic_back_pain        67.0         m                  360.0
# 1        VP04  chronic_back_pain        54.0         f                  120.0
# 2        VP05  chronic_back_pain        64.0         f                   96.0
# 3        VP07  chronic_back_pain        41.0         m                   22.0
# 4        VP08  chronic_back_pain        72.0         m                  480.0
# ..        ...                ...         ...       ...                    ...
# 83      vpH64            various        79.0         f                    NaN
# 84      vpH66            various        56.0         f                    NaN
# 85      vpH67            various        54.0         m                    NaN
# 86      vpH68            various        55.0         f                    NaN
# 87      vpH69            various        53.0         m                    NaN
#
#     Avg. painIntensity (0 – 10)  Curr. Pain Intensity(0 – 10)   BDI   PDQ  \
# 0                           5.0                           5.0   3.0  28.0
# 1                           5.0                           4.0  35.0  14.0
# 2                           7.0                           5.0   7.0  16.0
# 3                           6.0                           7.0  15.0  22.0
# 4                           8.0                           8.0  11.0  10.0
# ..                          ...                           ...   ...   ...
# 83                          NaN                           NaN   NaN   NaN
# 84                          NaN                           NaN   NaN   NaN
# 85                          NaN                           NaN   NaN   NaN
# 86                          NaN                           NaN   NaN   NaN
# 87                          NaN                           NaN   NaN   NaN
#
#      MQS  VR-12 PCS  VR-12 MCS  PDI  Age (years)
# 0    4.0        NaN        NaN  NaN          NaN
# 1   31.7        NaN        NaN  NaN          NaN
# 2   11.4        NaN        NaN  NaN          NaN
# 3    6.1        NaN        NaN  NaN          NaN
# 4    8.4        NaN        NaN  NaN          NaN
# ..   ...        ...        ...  ...          ...
# 83   NaN        NaN        NaN  NaN         79.0
# 84   NaN        NaN        NaN  NaN         56.0
# 85   NaN        NaN        NaN  NaN         54.0
# 86   NaN        NaN        NaN  NaN         55.0
# 87   NaN        NaN        NaN  NaN         53.0
#
# [189 rows x 14 columns]

# %% [markdown]
# #### Check the metadata and set channel types

# %%
example_raw = mne.io.read_raw_brainvision(eeg_files_chronic_pain[0])
example_raw
# Out:
# Extracting parameters from /data0/practical-sose23/brain-age/data/bap/chronic_pain_patients/chronic_back_pain/preprocessed/Exp_eyes_closed_vp11_eyes_closed.vhdr...
# Setting channel info structure...
# /tmp/ipykernel_1439682/2177493425.py:1: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   example_raw = mne.io.read_raw_brainvision(eeg_files_chronic_pain[0])
# /tmp/ipykernel_1439682/2177493425.py:1: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   example_raw = mne.io.read_raw_brainvision(eeg_files_chronic_pain[0])
# <RawBrainVision | Exp_eyes_closed_vp11_eyes_closed.dat, 65 x 300004 (300.0 s), ~71 kB, data not loaded>

# %%
channel_to_channel_type = {ch_name:"eeg" for ch_name in example_raw.ch_names}
channel_to_channel_type.update({"LE":"misc", "RE":"misc"})
eeg_chs = [ch for ch in example_raw.ch_names if not (ch=="RE" or ch=="LE")]
example_raw.set_channel_types(channel_to_channel_type)
# Out:
# /tmp/ipykernel_1439682/179859254.py:4: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   example_raw.set_channel_types(channel_to_channel_type)
# <RawBrainVision | Exp_eyes_closed_vp11_eyes_closed.dat, 65 x 300004 (300.0 s), ~71 kB, data not loaded>

# %%
montage = mne.channels.make_standard_montage("standard_1020")
example_raw = example_raw.set_montage(montage)

# %%
channel_to_channel_type = {ch_name:"eeg" for ch_name in example_raw.ch_names}
channel_to_channel_type.update({"LE":"misc", "RE":"misc"})

# %%
for f in eeg_files_preprocessed:
    if not f.is_file():
        print(f)

# %% [markdown]
# ### Preprocess data

# %%
sfreq = 128
epoch_len = sfreq * 20

epochs = []
ages = []

for f in eeg_files_preprocessed[:20]:
    
    sub_id = get_subj_id(f)
    age = get_age(df_subj, f)
    raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
    
    raw.set_channel_types(channel_to_channel_type)
    raw = raw.crop(raw.tmin+30, raw.tmax-30)
    raw = raw.notch_filter(freqs=50, notch_widths=0.5)
    raw = raw.filter(l_freq=0.5, h_freq=sfreq//(2+1))

    raw = raw.resample(sfreq=sfreq)
    data = raw.get_data(picks=eeg_chs)
    
    sections = np.arange(0, data.shape[-1], epoch_len)
    epochs_subj = np.split(data, sections, axis=1)[1:-1]
    
    epochs.append(epochs_subj)
    ages.append(len(epochs_subj)*[age])
# Out:
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ...
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.3s finished
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: No coordinate information found for channels ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:11: RuntimeWarning: Not setting positions of 64 misc channels found in montage:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Oz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'TP9', 'TP10', 'LE', 'RE', 'P1', 'P2', 'C1', 'C2', 'FT9', 'FT10', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'PO9', 'Iz', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'PO10', 'CPz', 'POz']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(f, verbose=False, preload=True)
# /tmp/ipykernel_1439682/4198443740.py:13: RuntimeWarning: The unit for channel(s) AF3, AF4, C1, C2, C3, C4, C5, C6, CP1, CP2, CP3, CP4, CP5, CP6, CPz, Cz, F3, F4, F5, F6, F7, F8, FC1, FC2, FC3, FC4, FC5, FC6, FT10, FT7, FT8, FT9, Fp1, Fp2, Fpz, Fz, Iz, O1, O2, Oz, P1, P2, P3, P4, P5, P6, P7, P8, PO10, PO3, PO4, PO7, PO8, PO9, POz, Pz, T7, T8, TP10, TP7, TP8, TP9 has changed from NA to V.
#   raw.set_channel_types(channel_to_channel_type)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.25
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.00 Hz)
# - Upper passband edge: 50.75 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.00 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 42 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 42.00 Hz
# - Upper transition bandwidth: 10.50 Hz (-6 dB cutoff frequency: 47.25 Hz)
# - Filter length: 6601 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.4s finished

# %% [markdown]
# ### Neural network baseline

# %%
from torcheeg.models import EEGNet

# %%
hparams_eegnet = {
    "learning_rate":1e-5,
    "batch_size":32,
    "chunk_size":int(sfreq*1),
    "dropout":0.0,
    "kernel_1": sfreq//2,
    "kernel_2": sfreq//8,
    "F1":8,
    "F2":16,
    "depth_multiplier":2
}

eegnet = EEGNet(chunk_size=hparams_eegnet["chunk_size"],
               num_electrodes=63,
               dropout=hparams_eegnet["dropout"],
               kernel_1=hparams_eegnet["kernel_1"],
               kernel_2=hparams_eegnet["kernel_2"],
               F1=hparams_eegnet["F1"],
               F2=hparams_eegnet["F2"],
               D=hparams_eegnet["depth_multiplier"],
               num_classes=1)

# %% [markdown]
# #### Configure transforms

# %%
def _randomcrop(x, seq_len):
    idx = 0
    return x[:, idx:idx+seq_len]

# %%
mean_age = torch.tensor(round(df_subj["Age(years)"].mean(), 3))

randomcrop = partial(_randomcrop, seq_len=hparams_eegnet["chunk_size"])
# labelcenter = partial(_labelcenter, mean_age=round(df_subj["Age(years)"].mean(), 3))
labelbin = partial(_labelbin, y_lower=mean_age)
transforms = partial(_compose, transforms=[totensor, randomcrop, channelwise_norm, toimshape])
target_transforms = partial(_compose, transforms=[labelbin, totensor])

# %% [markdown]
# #### Split data across subjects

# %%
np.random.seed(42), np.random.shuffle(epochs)
np.random.seed(42), np.random.shuffle(ages)

n_train = int(0.8*len(epochs))

epochs_train = epochs[:n_train]
ages_train = ages[:n_train]

epochs_val = epochs[n_train:]
ages_val = ages[n_train:]

dataset_train = BrainAgeDataset(np.concatenate(epochs_train), np.concatenate(ages_train), 
                                transforms=transforms, target_transforms=target_transforms)
dataset_val = BrainAgeDataset(np.concatenate(epochs_val), np.concatenate(ages_val), 
                              transforms=transforms, target_transforms=target_transforms)

dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=hparams_eegnet["batch_size"], shuffle=True, drop_last=True)
dataloader_val = torch.utils.data.DataLoader(dataset_val, batch_size=hparams_eegnet["batch_size"], drop_last=True)

print(len(dataset_train), len(dataset_val))
# Out:
# 184 48

# %% [markdown]
# #### Check class balance

# %%
n_class_0 = 0
for x, y in dataset_train:
    n_class_0 += y.item()


print("% Subjects above the age threshold")  
print(f"train set: {100*n_class_0 / len(dataset_train):.3}")

n_class_0 = 0
for x, y in dataset_val:
    n_class_0 += y.item()

print(f"validation set: {100*n_class_0 / len(dataset_val):.3}")
# Out:
# % Subjects above the age threshold
# train set: 56.5
# validation set: 75.0

# %% [markdown]
# #### Visualize random data points

# %%
for eeg, age in dataloader_train.dataset:
    plt.figure(figsize=(12,5))
    print(eeg.mean(), eeg.std())
    plt.title(f"age label: {str(age.item())}")
    plt.imshow(eeg[0])
    
    plt.plot(eeg[0].T + torch.arange(eeg.shape[1]).unsqueeze(0), "r", alpha=0.25)
    plt.xlabel(f"time [@{sfreq}Hz]")

    plt.show()
    break
# Out:
# tensor(2.7201e-09) tensor(0.9961)

# %%
len(np.concatenate(epochs)), len(np.concatenate(ages)), \
len(np.concatenate(epochs_train)), len(np.concatenate(ages_train))
# Out:
# (232, 232, 184, 184)

# %%
class BrainAgeModel(pl.LightningModule):
        
    def __init__(self, model, hparams, loss_func, metric=None):
        super().__init__()
        self.model = model
        self.hparams.update(hparams)
        self.loss_func = loss_func
        self.metric = metric
        
    def forward(self, x):
        x = self.model(x)
        return x
    
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.hparams["learning_rate"])
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        val_loss = self.loss_func(y_hat.squeeze(), y.squeeze())
        self.log("validation loss", val_loss, on_step=True, on_epoch=True, prog_bar=True)
        if self.metric:
            metric_val = self.metric["func"](y_hat.squeeze(), y.squeeze())
#             print(f"==================Val Acc: {metric_val} =======================")
#             print(y_hat.squeeze()[:2], y.squeeze()[:2])
            self.log("val_"+self.metric["name"], metric_val, on_step=True, on_epoch=True, prog_bar=True)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.forward(x)
        loss = self.loss_func(y_hat.squeeze(), y.squeeze())
        self.log("training loss", loss, on_step=True, on_epoch=True, prog_bar=True)
        if self.metric:
            metric_val = self.metric["func"](y_hat.squeeze(), y.squeeze())
#             print(f"==================Train Acc: {metric_val} =======================")
#             print(y_hat.squeeze()[:2], y.squeeze()[:2])
            self.log("train_"+self.metric["name"], metric_val, on_step=True, on_epoch=True, prog_bar=True)

        return loss

# %% [markdown]
# #### Set-up metrics

# %%
def score_accuracy(y_hat, y):
    return (y==torch.argmax(y_hat, dim=-1)).float().mean()

def score_binary_accuracy(y_hat, y):
    return (y==torch.round(y_hat)).float().mean()

def score_binary_accuracy_v2(y_hat, y):
    y_hat = torch.sigmoid(y_hat)
    return (y==torch.where(y_hat > 0.5, 1.0, 0.0)).float().mean()


def compute_r2(model, val_dataloader):
    model.eval(), model.cpu()
    rss, tss = 0, 0
    for batch in val_dataloader:
        x, y = batch
        y_hat = model.forward(x)
        rss += torch.nn.functional.mse_loss(y.squeeze(), y_hat.squeeze())
        tss += y.var()
    return 1 - rss/tss

# %% [markdown]
# ### Initialize model

# %%
model = BrainAgeModel(
    model=list(eegnet.modules())[0], 
    hparams=hparams_eegnet, 
    loss_func=torch.nn.functional.binary_cross_entropy_with_logits,#torch.nn.BCELoss(), 
    metric={"name":"binary accuracy", "func":score_binary_accuracy_v2})
print(model)
# Out:
# BrainAgeModel(
#   (model): EEGNet(
#     (block1): Sequential(
#       (0): Conv2d(1, 8, kernel_size=(1, 64), stride=(1, 1), padding=(0, 32), bias=False)
#       (1): BatchNorm2d(8, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Conv2dWithConstraint(8, 16, kernel_size=(63, 1), stride=(1, 1), groups=8, bias=False)
#       (3): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (4): ELU(alpha=1.0)
#       (5): AvgPool2d(kernel_size=(1, 4), stride=4, padding=0)
#       (6): Dropout(p=0.0, inplace=False)
#     )
#     (block2): Sequential(
#       (0): Conv2d(16, 16, kernel_size=(1, 16), stride=(1, 1), padding=(0, 8), groups=16, bias=False)
#       (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (2): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (3): ELU(alpha=1.0)
#       (4): AvgPool2d(kernel_size=(1, 8), stride=8, padding=0)
#       (5): Dropout(p=0.0, inplace=False)
#     )
#     (lin): Linear(in_features=64, out_features=1, bias=False)
#   )
# )

# %% [markdown]
# #### Test fwd pass

# %%
example_out = model(dataloader_train.dataset[0][0].unsqueeze(0))
example_out = model(next(iter(dataloader_train))[0])
example_out.shape, example_out.min(), example_out.max()
# Out:
# (torch.Size([32, 1]),
#  tensor(-23.2767, grad_fn=<MinBackward1>),
#  tensor(29.5713, grad_fn=<MaxBackward1>))

# %% [markdown]
# #### Specify experiment name and train

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

overfit_batches = 1
wandb.login()
logger = pl.loggers.WandbLogger(project="brain-age-ssl", name=f"EEGNet classification baseline on {overfit_batches} batches", 
                                save_dir="/data0/practical-sose23/brain-age", log_model=False)

early_stop_callback = EarlyStopping(monitor="validation loss", min_delta=0.00, patience=500, verbose=False, mode="max")

trainer = pl.Trainer(callbacks=[early_stop_callback], overfit_batches=1, max_epochs=500, accelerator="gpu", logger=logger)
Tuner(trainer).lr_find(model, dataloader_train)

trainer.fit(model, dataloader_train, dataloader_val)
wandb.finish()
# Out:
# wandb version 0.15.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.2
# Run data is saved locally in <code>/data0/practical-sose23/brain-age/wandb/run-20230520_131855-ubbb95au</code>
# Syncing run <strong><a href='https://wandb.ai/brain-age/brain-age-ssl/runs/ubbb95au' target="_blank">EEGNet classification baseline on 1 batches</a></strong> to <a href='https://wandb.ai/brain-age/brain-age-ssl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/brain-age/brain-age-ssl' target="_blank">https://wandb.ai/brain-age/brain-age-ssl</a>
#  View run at <a href='https://wandb.ai/brain-age/brain-age-ssl/runs/ubbb95au' target="_blank">https://wandb.ai/brain-age/brain-age-ssl/runs/ubbb95au</a>
# /u/home/swth/.conda/envs/my_brain_age_env/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /u/home/swth/.conda/envs/my_brain_age_env/lib/python ...
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(overfit_batches=1)` was configured so 1 batch will be used.
# /u/home/swth/.conda/envs/my_brain_age_env/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:72: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# You are using a CUDA device ('NVIDIA A40') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /u/home/swth/.conda/envs/my_brain_age_env/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:259: UserWarning: You requested to overfit but enabled train dataloader shuffling. We are turning off the train dataloader shuffling for you.
#   rank_zero_warn(
# /u/home/swth/.conda/envs/my_brain_age_env/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 256 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /u/home/swth/.conda/envs/my_brain_age_env/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:280: PossibleUserWarning: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7843, -20.4255], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7843, -20.4255], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7843, -20.4255], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7843, -20.4255], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7843, -20.4255], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7843, -20.4255], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7844, -20.4256], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7844, -20.4256], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7844, -20.4256], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7845, -20.4257], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7845, -20.4257], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7846, -20.4258], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7847, -20.4259], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7848, -20.4259], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7849, -20.4261], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7851, -20.4262], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7852, -20.4263], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7854, -20.4265], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7857, -20.4268], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7860, -20.4270], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7864, -20.4274], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7868, -20.4278], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7873, -20.4282], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7880, -20.4288], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7887, -20.4295], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7896, -20.4303], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7907, -20.4313], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7920, -20.4325], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7936, -20.4340], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7955, -20.4357], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7978, -20.4378], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8005, -20.4403], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8038, -20.4433], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8078, -20.4469], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8125, -20.4513], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8182, -20.4565], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8250, -20.4627], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8332, -20.4702], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8431, -20.4792], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8548, -20.4900], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8689, -20.5029], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.8857, -20.5184], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.9058, -20.5369], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.9298, -20.5591], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.9583, -20.5855], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.9923, -20.6170], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.0326, -20.6546], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.0803, -20.6992], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.1366, -20.7522], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.2030, -20.8148], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.2808, -20.8887], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.3718, -20.9756], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.4777, -21.0774], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.6004, -21.1961], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.7419, -21.3340], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-21.9042, -21.4932], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-22.0893, -21.6761], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-22.2993, -21.8849], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-22.5363, -22.1221], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-22.8023, -22.3897], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-23.0994, -22.6900], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-23.4296, -23.0253], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-23.7951, -23.3976], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-24.1982, -23.8095], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# `Trainer.fit` stopped: `max_steps=100` reached.
# Learning rate set to 7.585775750291837e-08
# Restoring states from the checkpoint path at /u/home/swth/brain-age/drafts/schwarz/.lr_find_1968ba1d-22e9-4b2d-a87e-5e7670ddc589.ckpt
# Restored all states from the checkpoint at /u/home/swth/brain-age/drafts/schwarz/.lr_find_1968ba1d-22e9-4b2d-a87e-5e7670ddc589.ckpt
# You are using a CUDA device ('NVIDIA A40') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type   | Params
# ---------------------------------
# 0 | model | EEGNet | 2.2 K
# ---------------------------------
# 2.2 K     Trainable params
# 0         Non-trainable params
# 2.2 K     Total params
# 0.009     Total estimated model params size (MB)
# ==================Train Acc: 1.0 =======================
# tensor([-24.6415, -24.2636], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-25.1279, -24.7627], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-25.6604, -25.3103], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-26.2427, -25.9102], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-26.8789, -26.5667], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-27.5736, -27.2849], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-28.3319, -28.0705], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-29.1597, -28.9298], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Sanity Checking: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2394, -23.3624], device='cuda:0') tensor([1., 1.], device='cuda:0')
# /u/home/swth/.conda/envs/my_brain_age_env/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 256 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2417, -23.3641], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2440, -23.3657], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2462, -23.3674], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2484, -23.3690], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2506, -23.3707], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2528, -23.3723], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2549, -23.3739], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2570, -23.3755], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2591, -23.3770], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2612, -23.3786], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2633, -23.3801], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2653, -23.3816], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2673, -23.3831], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2693, -23.3846], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2713, -23.3861], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2733, -23.3875], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2752, -23.3890], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2771, -23.3904], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2790, -23.3918], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2809, -23.3932], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2828, -23.3946], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2846, -23.3960], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2864, -23.3974], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2883, -23.3987], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2900, -23.4000], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2918, -23.4014], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2936, -23.4027], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2953, -23.4040], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2970, -23.4053], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.2987, -23.4065], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3004, -23.4078], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3021, -23.4090], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3037, -23.4103], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3054, -23.4115], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3070, -23.4127], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3086, -23.4139], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3102, -23.4151], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3118, -23.4163], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3133, -23.4174], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3149, -23.4186], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3164, -23.4197], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3179, -23.4208], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3194, -23.4219], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3209, -23.4231], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3223, -23.4242], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3238, -23.4252], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3252, -23.4263], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3266, -23.4274], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3281, -23.4284], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3295, -23.4295], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3308, -23.4305], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3322, -23.4315], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3336, -23.4325], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3349, -23.4335], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3362, -23.4345], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3375, -23.4355], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3388, -23.4365], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3401, -23.4374], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3414, -23.4384], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3426, -23.4393], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3439, -23.4403], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3451, -23.4412], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3464, -23.4421], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3476, -23.4430], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3488, -23.4439], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3499, -23.4448], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3511, -23.4457], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3523, -23.4465], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3534, -23.4474], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3546, -23.4483], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3557, -23.4491], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3568, -23.4499], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3579, -23.4508], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3590, -23.4516], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3601, -23.4524], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3612, -23.4532], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3622, -23.4540], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3633, -23.4548], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3643, -23.4556], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3654, -23.4563], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.3664, -23.4571], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ...
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4654, -23.5315], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4654, -23.5315], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4654, -23.5315], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4654, -23.5315], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4654, -23.5315], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4655, -23.5315], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4655, -23.5316], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4655, -23.5316], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4655, -23.5316], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4655, -23.5316], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4656, -23.5316], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4656, -23.5316], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4656, -23.5316], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4656, -23.5317], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4656, -23.5317], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4657, -23.5317], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4657, -23.5317], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4657, -23.5317], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4657, -23.5317], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4657, -23.5317], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4658, -23.5318], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4658, -23.5318], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4658, -23.5318], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4658, -23.5318], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4658, -23.5318], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4659, -23.5318], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4659, -23.5318], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4659, -23.5319], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4659, -23.5319], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4659, -23.5319], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4659, -23.5319], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4660, -23.5319], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4660, -23.5319], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4660, -23.5319], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4660, -23.5319], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4660, -23.5320], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4660, -23.5320], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4661, -23.5320], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4661, -23.5320], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4661, -23.5320], device='cuda:0') tensor([1., 1.], device='cuda:0')
# ==================Train Acc: 1.0 =======================
# tensor([-20.7842, -20.4254], device='cuda:0', grad_fn=<SliceBackward0>) tensor([0., 0.], device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ==================Val Acc: 0.5 =======================
# tensor([-11.4661, -23.5320], device='cuda:0') tensor([1., 1.], device='cuda:0')
# `Trainer.fit` stopped: `max_epochs=500` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_binary accuracy_epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_binary accuracy_step</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training loss_epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training loss_step</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_binary accuracy_epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_binary accuracy_step</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation loss_epoch</td><td>▁▂▂▃▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇███████████████████</td></tr><tr><td>validation loss_step</td><td>▁▂▂▃▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇███████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>499</td></tr><tr><td>train_binary accuracy_epoch</td><td>1.0</td></tr><tr><td>train_binary accuracy_step</td><td>1.0</td></tr><tr><td>trainer/global_step</td><td>499</td></tr><tr><td>training loss_epoch</td><td>0.0</td></tr><tr><td>training loss_step</td><td>0.0</td></tr><tr><td>val_binary accuracy_epoch</td><td>0.5</td></tr><tr><td>val_binary accuracy_step</td><td>0.5</td></tr><tr><td>validation loss_epoch</td><td>5.12615</td></tr><tr><td>validation loss_step</td><td>5.12615</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">EEGNet classification baseline on 1 batches</strong> at: <a href='https://wandb.ai/brain-age/brain-age-ssl/runs/ubbb95au' target="_blank">https://wandb.ai/brain-age/brain-age-ssl/runs/ubbb95au</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/data0/practical-sose23/brain-age/wandb/run-20230520_131855-ubbb95au/logs</code>

# %%
compute_r2(model, dataloader_val), \
compute_r2(model, dataloader_train)

# %%
# !nvidia-smi
